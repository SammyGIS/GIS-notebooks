# %% [markdown]
# <a href="https://colab.research.google.com/github/SammyGIS/GIS-notebooks/blob/main/python_google_nearby_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
import json
import os
import geopy.distance
import numpy as np

# %%
PATH = "D:\Workshop\Python_google_place_api\Data" # change the path only to the data path
DATA = "listings.csv"
    
def get_data(path=PATH, DATA = data):
    """
    args: csv data file format
    """
    data_path = os.path.join(path,data)
    return pd.read_csv(data_path)

# %%
listing_data = get_data()
listing_data.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  13913  https://www.airbnb.com/rooms/13913  20211207182339   2021-12-09
# 1  15400  https://www.airbnb.com/rooms/15400  20211207182339   2021-12-09
# 2  17402  https://www.airbnb.com/rooms/17402  20211207182339   2021-12-09
# 3  17506  https://www.airbnb.com/rooms/17506  20211207182339   2021-12-09
# 4  25123  https://www.airbnb.com/rooms/25123  20211207182339   2021-12-09
#
#                                                 name  \
# 0                Holiday London DB Room Let-on going
# 1                Bright Chelsea  Apartment. Chelsea!
# 2              Superb 3-Bed/2 Bath & Wifi: Trendy W1
# 3  Boutique Chelsea/Fulham Double bed 5-star ensuite
# 4                  Clean big Room in London (Room 1)
#
#                                          description  \
# 0  My bright double bedroom with a large window h...
# 1  Lots of windows and light.  St Luke's Gardens ...
# ...

# %%
len(listing_data.columns)
# Out:
# 74

# %%
 #  we have 74 columns, let print the list of columns
[items for items in listing_data.columns]
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'description',
#  'neighborhood_overview',
#  'picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'latitude',
#  'longitude',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bathrooms_text',
#  'bedrooms',
#  'beds',
#  'amenities',
#  'price',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
# ...

# %%
# checking if there is any data with missing long and lats
listing_data.latitude.isnull().sum(), listing_data.longitude.isnull().sum()
# Out:
# (0, 0)

# %%
# for testing i will use the first 50 rows in the dataset
data = listing_data.loc[:49]
len(data)
data.head(2)
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  13913  https://www.airbnb.com/rooms/13913  20211207182339   2021-12-09
# 1  15400  https://www.airbnb.com/rooms/15400  20211207182339   2021-12-09
#
#                                   name  \
# 0  Holiday London DB Room Let-on going
# 1  Bright Chelsea  Apartment. Chelsea!
#
#                                          description  \
# 0  My bright double bedroom with a large window h...
# 1  Lots of windows and light.  St Luke's Gardens ...
#
#                                neighborhood_overview  \
# 0  Finsbury Park is a friendly melting pot commun...
# 1                                     It is Chelsea.
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...    54730
# 1  https://a0.muscache.com/pictures/428392/462d26...    60302
#
#                                   host_url  ... review_scores_communication  \
# ...

# %%
cords = ["latitude","longitude"]
data[cords]
# Out:
#         latitude  longitude
# 0      51.568610  -0.112700
# 1      51.487800  -0.168130
# 2      51.521950  -0.140940
# 3      51.479350  -0.197430
# 4      51.574380  -0.210810
# ...          ...        ...
# 66636  51.419345  -0.079681
# 66637  51.502002  -0.276895
# 66638  51.599308  -0.114763
# 66639  51.510407  -0.193729
# 66640  51.491864  -0.098225
#
# [66641 rows x 2 columns]

# %%
# data = pd.read_csv("/content/data_50.csv")
# dataframe = data.loc[0:1]
# dataframe
# Out:
#       id                         listing_url     scrape_id last_scraped  \
# 0  13913  https://www.airbnb.com/rooms/13913  2.021120e+13    12/9/2021
# 1  15400  https://www.airbnb.com/rooms/15400  2.021120e+13    12/9/2021
#
#                                   name  \
# 0  Holiday London DB Room Let-on going
# 1  Bright Chelsea  Apartment. Chelsea!
#
#                                          description  \
# 0  My bright double bedroom with a large window h...
# 1  Lots of windows and light.  St Luke's Gardens ...
#
#                                neighborhood_overview  \
# 0  Finsbury Park is a friendly melting pot commun...
# 1                                     It is Chelsea.
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...    54730
# 1  https://a0.muscache.com/pictures/428392/462d26...    60302
#
#                                   host_url  ... review_scores_communication  \
# ...

# %%
# Searching area around a particualr point of interest, using  Google Near by API with a defined RADIUS

API_KEY = "AIzaSyCbrqiZJu_TKq81FDTcaHCcjHe57CJ8ws0"    # input your API KEY
radius = 1000  # Se your search radius in (radius in in meter)
rank = "prominence" 
keyword = "relaxation" #set a keyword that can be associated with the search you are intresed in

name_list = []
lat_list = []
lng_list = []
venues_list = []
distance_list = []


def get_location_details(input_data:'dataframe') :
    
    """
    args: file is the datafrme where the locational attributes is stored
    
    return: exported csv files
    
    """
    


    # extracting the long and lat using for iterrows.
    for ID,col in input_data.iterrows():
        
        latitude = col['latitude']
        longitude = col['longitude']

        
        # url query
#         url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={},{}&radius{radius}
#                     &type={venue}&keyword={}&key ={API_KEY}"

        url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={latitude},{longitude}&radius={radius}&rankby={rank}&keyword={keyword}&key={API_KEY}"
        
       # sending a get request to the url
        with requests.Session() as session:
          response = session.get(url)
          file = json.loads(response.text)
          
          venues_list.append([(
            col["name"],
            latitude,
            longitude,
            item.get("name"),
            item.get("geometry").get("location").get("lat"),
            item.get("geometry").get("location").get("lng"),
            item.get("types")[0]) for item in file.get("results")])
          
        nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])

        nearby_venues.columns = ['name',
                  "latitude",
                  "longitude",
                  'venue', 
                  'venue_latitude', 
                  'venue_longitude', 
                  'venue_category']

  
    # for ID, col in nearby_venues.iterrows():
    #   dist = geopy.distance.geodesic((col["latitude"],col["longitude"]),(col["venue_latitude"], col["venue_longitude"]))
    #   distance_list.append(dist.meters)

    # nearby_venues["distance_to_poi"] = distance_list
    
    return nearby_venues

# %%
# call the function
df = get_location_details(dataframe)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1ec07a873070> in <module>()
#       1 # call the function
# ----> 2 df = get_location_details(dataframe)
#       3 df.head()
#
# NameError: name 'dataframe' is not defined

# %%
def distance_btw_points(nearby_venues):

  distance_list = []

  for ID, col in nearby_venues.iterrows():
    dist = geopy.distance.geodesic((col["latitude"],col["longitude"]),(col["venue_latitude"], col["venue_longitude"]))
    distance_list.append(round(dist.meters))
    
  nearby_venues["distance_to_poi"] = distance_list

  
  table = pd.pivot_table(nearby_venues,values =['distance_to_poi'], index = ['name', 'latitude', 'longitude', 'venue', 'venue_latitude',
       'venue_longitude'],columns=['venue_category'],fill_value=0)
  
  data = table.reset_index()

  
    
  return data

# %%
data2 = distance_btw_points(df)
data2.head()
# Out:
#                                                name latitude longitude  \
# venue_category
# 0               Bright Chelsea  Apartment. Chelsea!  51.4878  -0.16813
# 1               Bright Chelsea  Apartment. Chelsea!  51.4878  -0.16813
# 2               Bright Chelsea  Apartment. Chelsea!  51.4878  -0.16813
# 3               Bright Chelsea  Apartment. Chelsea!  51.4878  -0.16813
# 4               Bright Chelsea  Apartment. Chelsea!  51.4878  -0.16813
#
#                                          venue venue_latitude venue_longitude  \
# venue_category
# 0                                       GinSen      51.487825       -0.167474
# 1                       Kiyora Beauty & Health      51.492452       -0.177279
# 2               Mind Calm Professional Massage      51.493788       -0.168683
# 3                                       Monnáy      51.489786       -0.175300
# 4                        N & N J Knightsbridge      51.497699       -0.164709
#
# ...

# %%
data2.reset_index(drop=True) 
data2
# Out:
#                                                name  latitude longitude  \
# venue_category
# 0               Bright Chelsea  Apartment. Chelsea!  51.48780  -0.16813
# 1               Bright Chelsea  Apartment. Chelsea!  51.48780  -0.16813
# 2               Bright Chelsea  Apartment. Chelsea!  51.48780  -0.16813
# 3               Bright Chelsea  Apartment. Chelsea!  51.48780  -0.16813
# 4               Bright Chelsea  Apartment. Chelsea!  51.48780  -0.16813
# 5               Bright Chelsea  Apartment. Chelsea!  51.48780  -0.16813
# 6               Bright Chelsea  Apartment. Chelsea!  51.48780  -0.16813
# 7               Bright Chelsea  Apartment. Chelsea!  51.48780  -0.16813
# 8               Bright Chelsea  Apartment. Chelsea!  51.48780  -0.16813
# 9               Bright Chelsea  Apartment. Chelsea!  51.48780  -0.16813
# 10              Holiday London DB Room Let-on going  51.56861  -0.11270
# 11              Holiday London DB Room Let-on going  51.56861  -0.11270
# ...

# %%
data2.to_csv("data.csv")
